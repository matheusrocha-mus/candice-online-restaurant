# %%
#Matheus Caetano Rocha - 29/04/2022

import os
clear = lambda: os.system('cls')

inp = ""
value = ""
validInput = True


def yes_no ():
    print ("1) Yes \n 2) No \n")
    while True:
        inp = input ()
        print ("TESTEEEEEEE")
        if inp == "1" or inp == "2":
            validInput = True
            value = inp
            break

        else:
            validInput = False
            value = "\n Please type 1 for 'Yes' or 2 for 'No'. \n"
            print (value)
    print ("O PROBLEMA TÁ AÍ EMBAIXO Ó")
    return value
    print ("DEU BOM SUCESSOOOOO")


def farewell ():
    print ("\n Thank you for your visit! \n")
    return


def choose_meal ():
    while True:
        inp = input ()
        if inp == "0" or inp == "1" or inp == "2" or inp == "3" or inp == "4":
            validInput = True
            value = inp

        else:
            validInput = False
            value = "\n Please enter the number between 1 and 4 that matches the desired option. If you want to cancel and exit, type 0. \n"
            print (value)

        if (validInput == True):
            break
    return value


def meal_exit_checkout ():
    print ("0) Cancel and exit \n \n 1) Dish \n 2) Dessert \n 3) Drink \n \n 4) Finish and go to checkout \n")
    while True:
        inp = input ()
        if inp == "0" or inp == "1" or inp == "2" or inp == "3" or inp == "4":
            validInput = True
            value = inp

        else:
            validInput = False
            value = "\n Please enter the number between 1 and 3 that matches the desired option. If you want to cancel and exit, type 0. \n"
            print (value)

        if (validInput == True):
            break
    return value


def meal_exit ():
    print ("0) cancel and exit \n \n 1) Dish \n 2) Dessert \n 3) Drink \n")
    while True:
        inp = input ()
        if inp == "0" or inp == "1" or inp == "2" or inp == "3":
            validInput = True
            value = inp

        else:
            validInput = False
            value = "\n Please enter the number between 1 and 3 that matches the desired option. If you want to cancel and exit, type 0. \n"
            print (value)

        if (validInput == True):
            break
    return value


#def start():

meal = ["Vegan", "Fish", "Chicken", "Beef", "Pineapple", "Diet icecream", "Diet mousse", "Chocolate mousse", "Tea", "Orange juice", "Melon juice", "Diet soda"]
price = [8.50, 12.30, 7.50, 10.50, 1.50, 3.50, 3.00, 2.50, 1.00, 2.50, 3.00, 2.00]
kcal = [180, 230, 250, 350, 75, 110, 170, 200, 20, 70, 100, 65]
#    int I, E, kcalFinal = 0
#    float priceFinal = 0.0, priceFloat [12]
#    str entry = ""

#    const str CAMINHO = "C:/ProgramData/UNIVALI/Portugol Studio/dados.txt"

print ("Hello! Welcome to the Candice Restaurant official website. Would you like to see the menu? \n \n")

yes_no ()
clear ()

if inp == "2":
    farewell ()


elif inp == "1":

    for I in range (12):
        if I == 0:
            print ("\n DISH \n ------------------------------- \n")

        elif I == 4:
            print ("\n DESSERT \n ------------------------------- \n")

        elif I == 8:
            print ("\n DRINK \n ------------------------------- \n")

        print (meal[I], " - $", format(price[I], ',.2f'), " - ", kcal [I], " kcal \n")

    print ("\n Would you like to make an order? \n \n")

    yes_no ()
    clear ()

    if inp == "2":
        farewell ()


    elif inp == "1":

        while True:

            file = open ("order.txt", "w")
            file.close()

            print ("\n Choose below which meal you would like to order: \n \n")

            meal_exit ()

            while inp == "1" or inp == "2" or inp == "3":

                if inp == "1":
                    print ("\n Choose a dish: \n \n")
                    print ("0 - Cancel and exit \n \n")
                    for I in range(1, 4):
                        print (I, ") ", meal [I - 1], " - $", price [I - 1], " - ", kcal [I - 1], " kcal \n")

                    choose_meal ()
                    file = open ("order.txt", "a")
                    E = int (value)
                    E = E - 1
                    entry = (E + "\n")
                    file.write(entry)
                    file.close()


                elif inp == "2":
                    print ("\n Choose a dessert:: \n \n")
                    print ("0 - Cancel and exit \n \n")
                    for I in range(1, 4):
                        print (I, ") ", meal [I + 3], " - $", price [I + 3], " - ", kcal [I + 3], " kcal \n")

                    choose_meal ()
                    file = open ("order.txt", "a")
                    E = int (value)
                    E = E + 3
                    entry = str (E + "\n")
                    file.write(entry)
                    file.close()


                elif inp == "3":
                    print ("\n Choose a drink: \n \n")
                    print ("0 - Cancel and exit \n \n")
                    for I in range(1, 4):
                        print (I, ") ", meal [I + 7], " - $", price [I + 7], " - ", kcal [I + 7], " kcal \n")

                    choose_meal ()
                    file = open ("order.txt", "a")
                    E = int (value)
                    E = E + 7
                    entry = str (E + "\n")
                    file.write(entry)
                    file.close()

                clear ()

                if inp == "0":
                    farewell ()

                elif inp != "0":
                    print ("\n Would you like to order anything else? \n \n")
                    meal_exit_checkout ()

            clear ()

            if inp == "0":
                farewell ()

            elif inp == "4":

                print ("\n CHECKOUT \n")
                print ("----------------------------------- \n")

#                    while (not Arquivos.fim_arquivo (arquivo))
#                        str line = Arquivos.ler_linha (arquivo)
#                        if line != "":

#                    file1 = open('myfile.txt', 'r')
#                    count = 0

#                    while True:
#                        count += 1
#                        line = file1.readline()
#                        if not line:
#                            break

                file = open ("order.txt", "r")
                while True:
                    line = file.readline ()
                    E = int (line)
                    print (meal [E], " - $", format(price[I], ',.2f'), " - ", kcal [E], " kcal \n")
                    priceFinal = priceFinal + price [E]
                    kcalFinal = kcalFinal + kcal [E]
                    if not line:
                        break
                file.close()


                print ("=================================== \n")

                print ("TOTAL: $", priceFinal, "0 - ", kcalFinal, " kcal \n \n")

                priceFinal = 0.0
                kcalFinal = 0

                print ("Would you like to make another order as a new customer? \n \n")

                yes_no ()
                clear ()

                if inp == "2": 
                    farewell ()


            if inp != "1":
                break
# Out:
# Hello! Welcome to our restaurant's website. Would you like to see the menu?
#
#
# 1) Yes
#  2) No
#
# 1
# TESTEEEEEEE
# O PROBLEMA TÁ AÍ EMBAIXO Ó
